# %% [markdown]
# # PartLabeler in a notebook
# The same annotator as the local page (`ui/canvas.js`), hosted by anywidget, which is how it runs on Colab.

# %%
from ui.host_widget import Annotator

Annotator("data/projects/example_white")
